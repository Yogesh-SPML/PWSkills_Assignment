# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [markdown]
# ```
# Matplotlib is a Python library that is used to create 2D graphs and plots. It is used to visualize data in various formats, such as line
# charts, scatter plots, bar charts, histograms, and pie charts. Matplotlib is a
# popular library for data visualization because it is easy to use and produces high-quality graphics.
#
# The five plots that can be plotted using the Pyplot module of Matplotlib are:
#
# 1. Line chart
# 2. Scatter plot
# 3. Bar chart
# 4. Histogram
# 5. Pie chart
# ```

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.

# %% [markdown]
# A scatter plot is a type of plot that displays values for two variables for a set of data. The data is displayed as a collection of points, where each point represents an observation in the dataset.

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
plt.subplots(figsize=(4, 4))
plt.scatter(x, y )
plt.title('Scatter Plot of X and Y')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# ```
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:
# import numpy as np
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])
# ```

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create data
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])

x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])

x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])

x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])


fig, axs = plt.subplots(2, 2)


axs[0, 0].plot(x1, y1)
axs[0, 1].plot(x2, y2)
axs[1, 0].plot(x3, y3)
axs[1, 1].plot(x4, y4)


axs[0, 0].set_title('Line Plot 1')
axs[0, 1].set_title('Line Plot 2')
axs[1, 0].set_title('Line Plot 3')
axs[1, 1].set_title('Line Plot 4')


axs[0, 0].set_xlabel('X')
axs[0, 0].set_ylabel('Y')
axs[0, 1].set_xlabel('X')
axs[0, 1].set_ylabel('Y')
axs[1, 0].set_xlabel('X')
# Out:
# Text(0.5, 0, 'X')

# %% [markdown]
# ```
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# import numpy as np
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
# profit = np.array([3000, 8000, 1000, 10000])
# ```

# %% [markdown]
# A bar plot is a type of plot that displays categorical data with rectangular bars. The height or length of each bar is proportional to the value that it represents. It is used to compare different categories or groups of data. It is also used to show changes in data over time.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create data
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# Create a bar plot
plt.bar(company, profit)

# Add title and labels
plt.title('Company Profits')
plt.xlabel('Company')
plt.ylabel('Profit')

# Show plot
plt.show()

# Create a horizontal bar plot
plt.barh(company, profit)

# Add title and labels
plt.title('Company Profits')
plt.xlabel('Profit')
plt.ylabel('Company')

# Show plot
plt.show()
